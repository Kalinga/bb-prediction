# %%
import matplotlib.pyplot as plt

# %%
plt.title('Prediction speed ')
plt.xlabel('Configuration')
plt.ylabel('seconds')
x = ['conf1', 'conf2', 'conf3']
y = [0.0161, 0.0626, 0.0161 ]
plt.plot(x, y)
plt.show()

# %% [markdown]
# Conf4:
#
# 0.016732095034023006
# mean distance 51.451523196412545
#
# IoU > 0.25
# avg prediction 0.0163
# Avg accuracy 0.6603
#
# IoU > 0.30
# 0.01662773432005953
# 0.6050099807240044
#
# IoU > 0.35
# 0.01657474652198198
# 0.5540008616771459
#
# IoU > 0.40
# 0.016720594661845223
# 0.49998988208842166
#
# IoU > 0.45
# 0.016539601833925697
# 0.44167176936117825
#
# IoU > 0.5
# avg prediction speed 0.0161
# Avg accuracy 0.39

# %% [markdown]
# conf 5 Test data set (30 videos)
# %model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
# model.add(Dropout(0.1))
# 3 more layers
#
# 0.06434447144167507
# mean distance 54.20351458010046
#
# IoU > 0.25 0.0625 0.627
#
# IoU > 0.30
# 0.06360451078261595
# 0.5775315792049909
#
# IoU > 0.35
# 0.06433070292862257
# 0.532167350614291
#
# IoU > 0.40
# 0.0641443693819561
# 0.49121471619821067
#
# IoU > 0.45 0.0626 0.444
#
# IoU > 0.50 0.062 0.389

# %% [markdown]
# conf 6 Test data set (30 videos)
# trained for 1000epochs
# IoU > 0.50
# 0.016 0.351
#
# IoU > 0.45
# 0.016 0.410
#
# IoU > 0.25
# 0.016 0.636

# %%
conf 7 Test data set (30 videos) 15fin_15ffuture
trained for 1000epochs
seq 15 future prediction 15 frames
0.009959263069533682
mean distance 29.731158259219043

IoU > 0.25
0.009677514215689608
0.8521200354259376

IoU > 0.30
0.00964590959888664
0.815764006238299

IoU > 0.35
0.009684376866566076
0.7778886491528938

IoU > 0.40
0.009624341934755825
0.7255014532283475

IoU > 0.45
0.009671343104152725
0.6700972952993102

IoU > 0.50
0.009691297208945718
0.6088618974640324

# %%
conf 8 Test data set (30 videos) 15fin_30ffuture
trained for 300 epochs
n_seq = 15
n_seq_future = 30

0.00958738078039744
mean distance 56.11528065576683

IoU > 0.50
0.009444540799017362
0.3335751734170474

IoU > 0.45
0.009451603079828863
0.3908785624721616

IoU > 0.40
0.00945801933210482
0.4509981208749086

IoU > 0.35
0.009443213526219837
0.5136326136004274

IoU > 0.30
0.009390612401125441
0.5698031308322636

IoU > 0.25
0.00951616896884005
0.6265302315936774

# %%
conf9_300e_60ffuture-model.h5 15fin_60ffuture
Test data set (30 videos)
trained for 300 epochs
n_seq = 15
n_seq_future = 60

0.009806662688561453
mean distance 163.342023464165

IoU > 0.50
0.009625284327485394
0.08257019919395786

IoU > 0.45
0.009776908634768648
0.10156051647141277

IoU > 0.40
0.009614824180712805
0.12091580631908329
IoU > 0.35
0.00954425587993056
0.13896674673635315

IoU > 0.30
0.00969599015912523
0.161640373836332

IoU > 0.25
0.00971825815710229
0.18370503137154917

15 15 conf 7
15 30 conf 8
15 60 conf 9

15 30 conf 8
30 30 conf 10
60 30 conf 11
# Out:
#   File "<ipython-input-1-210a0acd8e5d>", line 2
#     Test data set (30 videos)
#             ^
# SyntaxError: invalid syntax

# %%
conf10_300e_30ffuture-model.h5 30fin_30ffuture
Test data set (30 videos)
trained for 300 epochs
n_seq = 30
n_seq_future = 30

0.016123595002118934
mean distance 55.63944493632286

IoU > 0.50
0.016114993099097405
0.34375639936406904

IoU > 0.45
0.01603684988907046
0.40434060434937097

IoU > 0.40
0.016063256104376544
0.46194874346562065

IoU > 0.35
0.01563256419132377
0.5195613954998061

IoU > 0.30
0.015744991551256925
0.5668610219270049

IoU > 0.25
0.015854311635445074
0.6220304989701484

# %%
conf11_300e_60_30ffuture-model.h5
Test data set (30 videos)
trained for 300 epochs
n_seq = 60
n_seq_future = 30

0.026841848210956712
mean distance 57.55966844970537

********************
IoU >  0.5
0.026687484222870653
0.6218337609169805, 0.5777226433520168,0.5334484766349592,0.48895522015612464,0.4380914437677812,0.3843430688288686
********************
IoU >  0.45
0.026518725140064606
0.6218337609169805, 0.5777226433520168,0.5334484766349592,0.48895522015612464,0.4380914437677812,
********************
IoU >  0.4
0.026701879456029982
0.6218337609169805, 0.5777226433520168,0.5334484766349592,0.48895522015612464,
********************
IoU >  0.35
0.027114767454427504
0.6218337609169805, 0.5777226433520168,0.5334484766349592,
********************
IoU >  0.3
0.027081554648285166
0.6218337609169805, 0.5777226433520168,
********************
IoU >  0.25
0.02700777144552382
0.6218337609169805

# %%
conf121_300e_60_60ffuture-model.h5
Test data set (30 videos)
trained for 300 epochs
n_seq = 60
n_seq_future = 60

# %%
plt.title('Prediction Accuracy based on IoU - prediction-at-30frames ')
plt.xlabel('IoU')
plt.ylabel('accuracy')

# conf 8 15 30
x1 = [0.25,  0.30,  0.35,  0.40,  0.45,  0.50]
y1 = [0.626, 0.569, 0.513, 0.450, 0.390, 0.333]
# plotting the line 1 points 
plt.plot(x1, y1, label = "15-frames input")

# conf 10 30 30 
x2 = [0.25,  0.30,  0.35,  0.40,  0.45,  0.50]
y2 = [0.622, 0.566, 0.519, 0.461, 0.404, 0.343]
# plotting the line 2 points 
plt.plot(x2, y2, label = "30-frames input")

# conf 11 60 30 
x3 = [0.25,  0.30,  0.35,  0.40,  0.45,  0.50]
y3 = [0.621, 0.577, 0.533, 0.488, 0.438, 0.384]
# plotting the line 3 points 
plt.plot(x3, y3, label = "60-frames input")

# show a legend on the plot
plt.legend()
plt.savefig("prediction-at-30frames.png")
# Display a figure.
plt.show()

# %%
plt.title('Prediction Accuracy based on IoU - prediction-with-15frames-input')
plt.xlabel('IoU')
plt.ylabel('accuracy')
# line 1 points
x1 = [0.25,  0.30,  0.35,  0.40,  0.45,  0.50]
y1 = [0.852, 0.816, 0.778, 0.725, 0.670, 0.609]
# plotting the line 1 points 
plt.plot(x1, y1, label = "15frames-future")

# line 2 points
x2 = [0.25,  0.30,  0.35,  0.40,  0.45,  0.50]
y2 = [0.627, 0.569, 0.513, 0.450, 0.390, 0.333]
# plotting the line 2 points 
plt.plot(x2, y2, label = "30frames-future")

# line 3 points
x3 = [0.25,  0.30,  0.35,  0.40,  0.45,  0.50]
y3 = [0.183, 0.161, 0.138, 0.120, 0.101, 0.082]
# plotting the line 3 points 
plt.plot(x3, y3, label = "60frames-future")

# show a legend on the plot
plt.legend()
plt.savefig("prediction-with-15frames-input.png")
# Display a figure.
plt.show()

# %%
plt.title('Prediction Accuracy based on mean center distance')
plt.ylabel('mean center distance')
plt.xlabel('Configuration')

x = ['15frames-future', '30frames-future', '60frames-future']
y = [29.73, 56.11, 163.34]
plt.plot(x, y)
plt.savefig("prediction-with-15frames-input-mean_distance_accuracy.png")
plt.show()
